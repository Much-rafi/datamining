# %% [markdown]
# # Tugas 2

# %% [markdown]
# ## Mencari Data Kategorikal
# 1. Lakukan proses diskritisasi dengan equal width dan equal frequency
# 2. Lakukan proses diskritisasi dengan basis entropy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st
import numpy as np

# %% [markdown]
# ## Data

# %%
url = "https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv"
df = pd.read_csv(url)
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
SepalLength = df['sepal.length']
SepalWidth = df['sepal.width']
PetalLength = df['petal.length']
PetalWith = df['petal.width']

# %%
labels = ['sempit', 'sedang', 'lebar']

# %% [markdown]
# ## Soal 1

# %% [markdown]
# ### Diskiritasi

# %% [markdown]
# Diskritisasi adalah kegiatan yang dilakukan untuk mengubah niai data numerik menjadi kategorial

# %% [markdown]
# ###Min , Max

# %%
SepalLength
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
SepalWidth
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal.width, Length: 150, dtype: float64

# %%
PetalLength
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal.length, Length: 150, dtype: float64

# %%
labels1 = ['sempit', 'sedang', 'lebar']
# LabelledBinning1 = pd.qcut(df2['petal.length'],len(labels1), True, labels1).value_counts()

# %%
MinMaxSepalLength = [np.min(df['sepal.length']),np.max(df['sepal.length'])]
MinMaxSepalWidth = [np.min(df['sepal.width']),np.max(df['sepal.width'])]
MinMaxPetalLength = [np.min(df['petal.length']),np.max(df['petal.length'])]
MinMaxPetalWith = [np.min(df['petal.width']),np.max(df['petal.width'])]

# %%
PetalWith
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal.width, Length: 150, dtype: float64

# %% [markdown]
# ###Data Equal Width

# %% [markdown]
# ####Data Sepal Length

# %%
Sepal_Length_Binning = pd.cut(df['sepal.length'],len(labels), True, labels)
Labelled_Sepal_Length_Binning = Sepal_Length_Binning.value_counts()
NoLabelled_Sepal_Length_Binning = pd.cut(df['sepal.length'],len(labels)).value_counts()
# IntervalBinning = pd.cut()

# %%
Labelled_Sepal_Length_Binning
# Out:
# sedang    71
# sempit    59
# lebar     20
# Name: sepal.length, dtype: int64

# %%
pd.concat((df['sepal.length'],Sepal_Length_Binning),axis=1).head(15)
# Out:
#    sepal.length sepal.length
# 0           5.1       sempit
# 1           4.9       sempit
# 2           4.7       sempit
# 3           4.6       sempit
# 4           5.0       sempit
# 5           5.4       sempit
# 6           4.6       sempit
# 7           5.0       sempit
# 8           4.4       sempit
# 9           4.9       sempit
# 10          5.4       sempit
# 11          4.8       sempit
# 12          4.8       sempit
# 13          4.3       sempit
# 14          5.8       sedang

# %% [markdown]
# ####Data Sepal Width

# %%
Sepal_Width_Binning = pd.cut(df['sepal.width'],len(labels), True, labels)
Labelled_Sepal_Width_Binning = Sepal_Width_Binning.value_counts()
NoLabelled_Sepal_Width_Binning = pd.cut(df['sepal.width'],len(labels)).value_counts()
# IntervalBinning = pd.cut()

# %%
Labelled_Sepal_Width_Binning
# Out:
# sedang    88
# sempit    47
# lebar     15
# Name: sepal.width, dtype: int64

# %%
NoLabelled_Sepal_Width_Binning
# Out:
# (2.8, 3.6]      88
# (1.998, 2.8]    47
# (3.6, 4.4]      15
# Name: sepal.width, dtype: int64

# %%
pd.concat((df['sepal.width'],Sepal_Width_Binning),axis=1).head(15)
# Out:
#    sepal.width sepal.width
# 0          3.5      sedang
# 1          3.0      sedang
# 2          3.2      sedang
# 3          3.1      sedang
# 4          3.6      sedang
# 5          3.9       lebar
# 6          3.4      sedang
# 7          3.4      sedang
# 8          2.9      sedang
# 9          3.1      sedang
# 10         3.7       lebar
# 11         3.4      sedang
# 12         3.0      sedang
# 13         3.0      sedang
# 14         4.0       lebar

# %% [markdown]
# ####Data Petal Length

# %%
Petal_Length_Binning = pd.cut(df['petal.length'],len(labels), True, labels)
Labelled_Petal_Length_Binning = Petal_Length_Binning.value_counts()
NoLabelled_Petal_Length_Binning = pd.cut(df['petal.length'],len(labels)).value_counts()
# IntervalBinning = pd.cut()

# %%
Labelled_Petal_Length_Binning
# Out:
# sedang    54
# sempit    50
# lebar     46
# Name: petal.length, dtype: int64

# %%
pd.concat((df['petal.length'],Petal_Length_Binning),axis=1)
# Out:
#     petal.length petal.length
# 0            1.4       sempit
# 1            1.4       sempit
# 2            1.3       sempit
# 3            1.5       sempit
# 4            1.4       sempit
# ..           ...          ...
# 145          5.2        lebar
# 146          5.0        lebar
# 147          5.2        lebar
# 148          5.4        lebar
# 149          5.1        lebar
#
# [150 rows x 2 columns]

# %% [markdown]
# ####Data Petal Width

# %%
Petal_Width_Binning = pd.cut(df['petal.width'],len(labels), True, labels)
Labelled_Petal_Width_Binning = Petal_Width_Binning.value_counts()
NoLabelled_Petal_Width_Binning = pd.cut(df['petal.width'],len(labels)).value_counts()
# IntervalBinning = pd.cut()

# %%
Labelled_Petal_Width_Binning
# Out:
# sedang    54
# sempit    50
# lebar     46
# Name: petal.width, dtype: int64

# %%
pd.concat((df['petal.width'],Petal_Width_Binning),axis=1)
# Out:
#     petal.width petal.width
# 0           0.2      sempit
# 1           0.2      sempit
# 2           0.2      sempit
# 3           0.2      sempit
# 4           0.2      sempit
# ..          ...         ...
# 145         2.3       lebar
# 146         1.9       lebar
# 147         2.0       lebar
# 148         2.3       lebar
# 149         1.8       lebar
#
# [150 rows x 2 columns]

# %% [markdown]
# ### Data Equal Frequency

# %% [markdown]
# #### Data Sepal Length

# %%
Qcut_Sepal_Length_Binning = pd.qcut(df['sepal.length'],len(labels), labels)
Labelled_Qcut_Sepal_Length_Binning = Qcut_Sepal_Length_Binning.value_counts()
NoLabelled_Qcut_Sepal_Length_Binning = pd.qcut(df['sepal.length'],len(labels)).value_counts()
# IntervalBinning = pd.qcut()

# %%
Labelled_Qcut_Sepal_Length_Binning
# Out:
# sedang    56
# sempit    52
# lebar     42
# Name: sepal.length, dtype: int64

# %%
pd.concat((df['sepal.length'],Qcut_Sepal_Length_Binning),axis=1)
# Out:
#     sepal.length sepal.length
# 0            5.1       sempit
# 1            4.9       sempit
# 2            4.7       sempit
# 3            4.6       sempit
# 4            5.0       sempit
# ..           ...          ...
# 145          6.7        lebar
# 146          6.3       sedang
# 147          6.5        lebar
# 148          6.2       sedang
# 149          5.9       sedang
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Data Sepal Width

# %%
Qcut_Sepal_Width_Binning = pd.qcut(df['sepal.width'],len(labels), labels)
Labelled_Qcut_Sepal_Width_Binning = Qcut_Sepal_Width_Binning.value_counts()
NoLabelled_Qcut_Sepal_Width_Binning = pd.qcut(df['sepal.width'],len(labels)).value_counts()
# IntervalBinning = pd.qcut()

# %%
Labelled_Qcut_Sepal_Width_Binning
# Out:
# sempit    57
# sedang    50
# lebar     43
# Name: sepal.width, dtype: int64

# %%
pd.concat((df['sepal.width'],Qcut_Sepal_Width_Binning),axis=1)
# Out:
#     sepal.width sepal.width
# 0           3.5       lebar
# 1           3.0      sedang
# 2           3.2      sedang
# 3           3.1      sedang
# 4           3.6       lebar
# ..          ...         ...
# 145         3.0      sedang
# 146         2.5      sempit
# 147         3.0      sedang
# 148         3.4       lebar
# 149         3.0      sedang
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Data Petal Length

# %%
Qcut_Petal_Length_Binning = pd.qcut(df['petal.length'],len(labels), labels)
Labelled_Qcut_Petal_Length_Binning = Qcut_Petal_Length_Binning.value_counts()
NoLabelled_Qcut_Petal_Length_Binning = pd.qcut(df['petal.length'],len(labels)).value_counts()
# IntervalBinning = pd.qcut()

# %%
Labelled_Qcut_Petal_Length_Binning
# Out:
# sedang    54
# sempit    50
# lebar     46
# Name: petal.length, dtype: int64

# %%
pd.concat((df['petal.length'],Qcut_Petal_Length_Binning),axis=1)
# Out:
#     petal.length petal.length
# 0            1.4       sempit
# 1            1.4       sempit
# 2            1.3       sempit
# 3            1.5       sempit
# 4            1.4       sempit
# ..           ...          ...
# 145          5.2        lebar
# 146          5.0        lebar
# 147          5.2        lebar
# 148          5.4        lebar
# 149          5.1        lebar
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Data Petal Width

# %%
Qcut_Petal_Width_Binning = pd.qcut(df['petal.width'],len(labels), labels)
Labelled_Qcut_Petal_Width_Binning = Qcut_Petal_Width_Binning.value_counts()
NoLabelled_Qcut_Petal_Width_Binning = pd.qcut(df['petal.width'],len(labels)).value_counts()
# IntervalBinning = pd.qcut()

# %%
Labelled_Qcut_Petal_Width_Binning
# Out:
# sedang    52
# sempit    50
# lebar     48
# Name: petal.width, dtype: int64

# %%
pd.concat((df['petal.width'],Qcut_Petal_Width_Binning),axis=1)
# Out:
#     petal.width petal.width
# 0           0.2      sempit
# 1           0.2      sempit
# 2           0.2      sempit
# 3           0.2      sempit
# 4           0.2      sempit
# ..          ...         ...
# 145         2.3       lebar
# 146         1.9       lebar
# 147         2.0       lebar
# 148         2.3       lebar
# 149         1.8       lebar
#
# [150 rows x 2 columns]

# %% [markdown]
# ## 2. Lakukan proses diskritisasi dengan basis entropy
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $thisisinline\int math$

# %%
misalData = df[["sepal.length"]]
misalData.describe()
# Out:
#        sepal.length
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000

# %% [markdown]
# Membuat Category Semua Data

# %%
np.random.seed(0)
misalData["category"] = np.where(np.random.choice(2,misalData.shape[0]) < 1,"sempit","sedang")
misalData
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      sepal.length category
# 0             5.1   sempit
# 1             4.9   sedang
# 2             4.7   sedang
# 3             4.6   sempit
# 4             5.0   sedang
# ..            ...      ...
# 145           6.7   sempit
# 146           6.3   sedang
# 147           6.5   sedang
# 148           6.2   sedang
# 149           5.9   sedang
#
# [150 rows x 2 columns]

# %% [markdown]
# Membuat fungsi GetOverollCategory (keseluruhan) yang digunakan untuk menghitung data keseluruhan yang nantinya digunakan untuk menghitung entropy

# %%
def GetOverollCategory(col):
  group = misalData.loc[:, :].groupby("category").count()
  a = group.loc["sempit", col]
  b = group.loc["sedang", col]
  return (a,b,a+b)

# %% [markdown]
# Fungsi splitter digunakan untuk membuat split antara value yang telah ditentukan lalu mengembalikan data yang telah dipisahkan

# %%
def splitter(value, col):
  #get data less and greater from value
  less = misalData[misalData[col] <= value]
  greater = misalData[misalData[col] > value]

  #calculate into category for each data
  less_group = less.loc[:, :].groupby("category").count()
  greater_group = greater.loc[:, :].groupby("category").count()

  #get value based on category
  less_category_A = less_group.loc["sedang",col]
  less_category_B = less_group.loc["sempit",col]
  greater_category_A = greater_group.loc["sedang",col]
  greater_category_B = greater_group.loc["sempit",col]

  return (
      [less_category_A, less_category_B, less_category_A + less_category_B],
      [greater_category_A, greater_category_B, greater_category_A + greater_category_B]
  )

# %% [markdown]
# Membuat fungsi entropy untuk mencari nilai entropy

# %%
def entropy (d):
  r1 = (d[0] / d[2]) * np.log2(d[0] / d[2])
  r2 = (d[1] / d[2]) * np.log2(d[1] / d[2])
  return np.sum([r1, r2]) * -1

# %% [markdown]
# Membuat fungsi info dan gain

# %%
def info(d):
  r1 = (d[0][2] / sample.shape[0]) * entropy(d[0])
  r2 = (d[1][2] / sample.shape[0]) * entropy(d[1])
  return r1 + r2

# %%
def gain(Einitial, Enew):
  return Einitial - Enew

# %% [markdown]
# Membuat Dinitial

# %%
D = GetOverollCategory("sepal.length")
entropy_d = entropy(D)
print(D)
print(entropy_d)
# Out:
# (68, 82, 150)
# 0.993707106604508

# %% [markdown]
# Melakukan beberapa tes split untuk menari informasi yang terbaik:
#
# Split 1 : 4.4

# %%
split1 = splitter(4.4, "sepal.length")
info_split1 = info(split1)
gain(entropy_d, info_split1)
# Out:
# 0.003488151753460178

# %% [markdown]
# Split 2 : 5.5

# %%
split2 = splitter(5.5, "sepal.length")
info_split2 = info(split2)
gain(entropy_d, info_split2)
# Out:
# 0.012302155146638905

# %% [markdown]
# Split 3 : 7.0

# %%
split3 = splitter(7.0, "sepal.length")
info_split3 = info(split3)
gain(entropy_d, info_split3)
# Out:
# 0.0005490214732508658

# %% [markdown]
# makin kecil nilai Gain terhadap nilai Einisial dan Enew, semakin baik akurasinya, maka split yang terbaik adalah 7.0 karena yang paling rendah
